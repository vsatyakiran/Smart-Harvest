# %%
crop = {
    'Apple':{
        'Duration':'''The duration for harvesting apples depends on the variety of the apple tree planted and the location.
        Generally, apple trees take about 2 to 5 years to bear fruit after planting, and harvesting usually begins in late summer
        to early fall, typically between August and October, depending on the variety.''',
        'Environment':{
            'Rainfall':'Apple trees generally require moderate rainfall, ideally around 600-800 mm annually. However, irrigation may be required during dry periods.',
            'Temperatue':'Apple trees thrive in temperate climates. They require a chilling period during winter (around 1000-1500 chill hours) to break dormancy and set fruit. During the growing season, temperatures between 15°C to 24°C are optimal.',
            'Humidity':'Apple trees prefer moderate humidity levels, ideally between 50% to 70%.',
            
        },
        'Soil':{
            'Nitrogen':'Apple trees require moderate levels of nitrogen for healthy growth, typically around 100-150 kg/ha per year.',
            'Phoshorous':'Phosphorus is important for root development and fruit production. Adequate levels should be maintained, typically around 50-80 kg/ha per year.',
            'Potassiun':'Potassium helps in overall tree vigor and fruit quality. Recommended levels are typically around 150-200 kg/ha per year.',
            'ph':'Apple trees prefer slightly acidic to neutral soil pH, ideally between 6.0 to 7.0.'
        },
        'Cultivate':{
            'Site selection':'Choose a well-drained site with full sunlight exposure for planting apple trees.',
            'Soil preparation':'Test the soil to determine its pH and nutrient levels. Amend the soil as needed to achieve optimal conditions.',
            'Planting:':'Plant apple trees during the dormant season, typically in late winter to early spring. Dig a hole large enough to accommodate the roots without bending or crowding. Plant the tree at the same depth as it was in the nursery.',
            'Training and pruning':'Train the young tree to a desired shape (central leader or open-center) and prune annually to remove dead, diseased, or crossing branches.',
            'Irrigation': 'Provide adequate water to newly planted trees and maintain soil moisture throughout the growing season, especially during dry periods.',
            'Fertilization': 'Apply fertilizers based on soil test results and the nutritional needs of the trees. Avoid excessive nitrogen fertilization, especially during fruit development.',
            'Pest and disease management': 'Monitor for pests and diseases regularly and take appropriate measures for control, including cultural, biological, and chemical methods.',
            'Harvesting': 'Harvest apples when they reach the desired size, color, and firmness. Twist or gently lift the apples from the tree, taking care not to damage the fruit or the spur.'
        }
    },
    'Banana':{
        'Duration':'The duration for harvesting bananas typically varies depending on the variety and environmental conditions. However, on average, it takes about 9 to 12 months for bananas to reach maturity and be ready for harvesting after planting.',
        'Environment':{'Rainfall':'Bananas require ample water for growth, with an ideal rainfall range of 1500-2500 mm per year.',
                      'Temperatue':'Optimal temperatures for banana growth range from 15°C to 35°C, with temperatures above 28°C being most favorable.',
                      'Humidity':'Bananas thrive in humid conditions, with relative humidity levels between 60% to 80% being ideal for growth.'
        },
        'Soil':{
            'Nitrogen':'Bananas require a significant amount of nitrogen for healthy growth, typically around 100-150 kg/ha.',
            'Phoshorous':'Adequate phosphorus is essential for root development and fruiting, with recommended levels around 60-100 kg/ha.',
            'Potassiun':'Potassium is crucial for banana plants, especially for fruit development, with recommended levels around 150-200 kg/ha.',
            'ph':'Bananas prefer slightly acidic to neutral soil pH, ideally between 5.5 to 7.0.',
        },
        'Cultivate':{
            'Site selection': 'Choose a well-drained site with full sunlight exposure for planting apple trees.',
            'Soil preparation': 'Clear the land of any debris or weeds and prepare the soil by plowing and leveling.',
            'Planting': 'Banana plants can be propagated through suckers or tissue culture. Plant the suckers or tissue-cultured plants in pits or trenches, spaced appropriately according to the variety.',
            'Fertilization': 'Apply fertilizers containing nitrogen, phosphorus, and potassium based on soil test results and crop requirements.',
            'Irrigation': 'Ensure regular and adequate irrigation, especially during dry periods, to maintain soil moisture levels.',
            'Weed Control': 'Control weeds through manual removal or the application of herbicides to prevent competition for nutrients and water.',
            'Pest and Disease Management': 'Monitor for pests and diseases regularly and take appropriate measures such as the application of pesticides or cultural practices to control them.',
            'Mulching': 'Apply mulch around the base of the plants to conserve soil moisture, suppress weeds, and maintain soil temperature.',
            'Support': 'Provide support to the plants, especially when they start bearing fruits, to prevent them from falling over due to the weight of the bunches.',
            'Harvesting': 'Harvest bananas when they reach maturity, indicated by changes in fruit color and firmness. Cut the entire bunch from the plant and handle with care to avoid damage.'
        }

    },
    'Blackgram':{
        'Duration':'The duration for harvesting blackgram typically ranges from 60 to 90 days after sowing, depending on various factors such as variety, environmental conditions, and agricultural practices.',
        'Environment':{'Rainfall':'Blackgram requires moderate rainfall ranging from 450-650 mm during its growth period. Excessive rainfall or waterlogging can be detrimental to its growth.',
                      'Temperatue':'The optimum temperature for blackgram cultivation is between 25°C to 35°C. It thrives in warm climates.',
                      'Humidity':'Blackgram prefers moderate to high humidity levels, ideally ranging from 60% to 80%.',
        },
        'Soil':{
            'Nitrogen':'Blackgram requires a sufficient amount of nitrogen for healthy growth. The recommended nitrogen level in the soil is around 20-30 kg/ha.',
            'Phoshorous':'Adequate phosphorus in the soil is essential for blackgram cultivation. The recommended phosphorus level in the soil is around 20-40 kg/ha.',
            'Potassiun':'Potassium is vital for blackgram plants, contributing to their overall growth and development. The recommended potassium level in the soil is around 20-40 kg/ha.',
            'ph':'Blackgram grows well in slightly acidic to neutral soil with a pH range of 6.0 to 7.5.',
        },
        'Cultivate':{
            'Land Preparation': 'Prepare the land by plowing and leveling to ensure proper soil aeration and drainage. Remove any weeds and debris from the field.',
            'Seed Selection': 'Choose high-quality blackgram seeds from a reliable source. Treat the seeds with recommended fungicides to prevent seed-borne diseases.',
            'Sowing': 'Sow the treated seeds in rows or broadcasting method, depending on the farming practices and equipment available. The ideal time for sowing blackgram is at the onset of the monsoon or during the rainy season.',
            'Irrigation': 'Provide adequate moisture to the crop, especially during the germination and flowering stages. Ensure proper irrigation scheduling to prevent water stress.',
            'Fertilization': 'Apply recommended doses of fertilizers containing nitrogen, phosphorus, and potassium based on soil test results and local agricultural recommendations. Incorporate organic matter to improve soil fertility.',
            'Weed Control': 'Keep the field weed-free by manual weeding or using herbicides, taking care not to damage the blackgram plants.',
            'Pest and Disease Management': 'Monitor the crop regularly for any signs of pests or diseases. Take appropriate measures such as applying recommended pesticides or adopting integrated pest management practices to control pest and disease outbreaks.',
            'Harvesting': 'Harvest the blackgram pods when they reach maturity, usually 60 to 90 days after sowing. The pods should turn yellowish-brown, and the seeds inside should be firm. Use appropriate harvesting equipment and techniques to minimize losses.',
            'Post-Harvest Management': 'Thresh the harvested pods to separate the seeds from the plant material. Dry the seeds thoroughly to reduce moisture content and prevent fungal growth. Store the dried seeds in a clean and dry place for future use or sale.'

        }
    },
    'Chickpea':{
        'Duration':'Duration for harvesting: The duration for harvesting chickpeas typically ranges from 90 to 150 days, depending on the variety and environmental conditions.',
        'Environment':{
            'Rainfall':'Chickpeas require a moderate amount of rainfall, ideally between 300 to 400 mm during the growing season. However, excessive rainfall can lead to waterlogging and affect the crop adversely.',
            'Temperatue':'Chickpeas thrive in temperatures ranging from 20°C to 30°C during the growing season. They can tolerate higher temperatures during the flowering and pod-filling stages but are sensitive to frost.',
            'Humidity':'Chickpeas prefer low to moderate humidity levels. High humidity can lead to fungal diseases and affect the yield.',
        },
        'Soil':{
            'Nitrogen':'Chickpeas are leguminous crops capable of fixing atmospheric nitrogen through their symbiotic relationship with nitrogen-fixing bacteria. However, a soil nitrogen content of around 40 to 60 kg/ha is considered optimal for chickpea cultivation.',
            'Phoshorous':'Chickpeas require phosphorus for healthy root development and overall growth. A soil phosphorus content of 20 to 40 kg/ha is suitable for chickpea cultivation.',
            'Potassiun':'Potassium is essential for various physiological processes in chickpeas, such as water regulation and nutrient uptake. A soil potassium content of 20 to 40 kg/ha is recommended for chickpea cultivation.',
            'ph':'Chickpeas prefer slightly acidic to neutral soils with a pH range of 6.0 to 7.5.',
        },
        'Cultivate':{
            'Land Preparation': 'Prepare the land by plowing and harrowing to obtain a fine tilth. Remove weeds and debris from the field.',
            'Seed Selection': 'Choose high-quality seeds of suitable chickpea varieties adapted to your local agro-climatic conditions.',
            'Sowing': 'Sow the seeds at the onset of the growing season, preferably when soil temperatures are above 10°C. The recommended planting depth is 3 to 5 cm.',
            'Spacing': 'Maintain row-to-row spacing of about 30 to 40 cm, and plant seeds at a spacing of 5 to 10 cm within the rows.',
            'Irrigation': 'Provide adequate irrigation during the initial stages of growth and flowering. Chickpeas are sensitive to water stress during flowering and pod development.',
            'Fertilization': 'Apply fertilizers based on soil test results. Chickpeas have a high demand for phosphorus and potassium, especially during the early stages of growth.',
            'Weed Control': 'Keep the field weed-free through manual weeding or herbicide application. Weeds compete with chickpea plants for nutrients, water, and sunlight.',
            'Pest and Disease Management': 'Monitor the crop regularly for pests and diseases. Common pests include pod borers, aphids, and pod flies, while diseases like Ascochyta blight and Fusarium wilt can affect chickpeas.',
            'Harvesting': 'Harvest chickpeas when the pods turn yellowish-brown and the seeds are firm. Allow the harvested pods to dry further before threshing to remove the seeds.'
        }
    },
    'Coconut':{
        'Duration':'The duration for harvesting coconut depends on various factors such as the variety of coconut, environmental conditions, and agricultural practices. Typically, coconuts start producing fruit around 5-6 years after planting, with peak production reached at around 10-20 years. Once mature, coconuts can be harvested year-round, with multiple harvests per year possible.',
        'Environment':{'Rainfall':'Coconut trees thrive in areas with high rainfall, ideally between 1500 to 2500 mm annually. However, they can also tolerate dry periods.',
                      'Temperatue':'Coconut palms prefer warm temperatures and cannot tolerate frost. The optimal temperature range for growth is between 27°C to 35°C.',
                      'Humidity':'They prefer high humidity levels, ideally around 60-70%.',
        },
        'Soil':{
            'Nitrogen':'Coconut palms require a moderate amount of nitrogen for healthy growth. Soil with nitrogen levels between 0.2% to 0.4% is suitable.',
            'Phoshorous':'Coconut palms need phosphorus for root development and fruit production. Soil with phosphorus levels between 10-30 ppm is ideal.',
            'Potassiun':'Potassium is essential for coconut palms, especially during fruit development. Soil with potassium levels between 0.2% to 0.4% is recommended.',
            'ph':'Coconut palms prefer slightly acidic to neutral soil pH, ideally between 5.5 to 7.0.',
        },
        'Cultivate':{
            'Site selection': 'Choose a location with well-drained soil, adequate sunlight, and protection from strong winds and salt spray. Coastal areas are often suitable for coconut cultivation.',
            'Land preparation': 'Clear the land of weeds and debris. Ensure proper drainage by contouring or providing adequate slope.',
            'Planting': 'Coconut palms are typically propagated from seeds or seedlings. Dig a planting hole large enough to accommodate the root system and plant the seedling at the same depth it was growing in the nursery.',
            'Spacing': 'Plant coconut palms at a distance of 7-10 meters apart to allow for proper growth and development.',
            'Irrigation': 'Provide irrigation during dry periods, especially for young coconut plants. Once established, coconut palms are relatively drought-tolerant.',
            'Fertilization': 'Apply organic or chemical fertilizers containing balanced nutrients, especially nitrogen, phosphorus, and potassium, according to soil test recommendations.',
            'Weed control': 'Keep the area around coconut palms free from weeds to reduce competition for nutrients and water.',
            'Pest and disease management': 'Monitor for pests and diseases regularly and take appropriate measures for control, including cultural, biological, and chemical methods.',
            'Harvesting': 'Coconuts can be harvested year-round once they reach maturity. Harvesting involves climbing the tree or using specialized tools to cut down the coconuts.'
        }
    },
    'Coffee':{
        'Duration':'The duration for harvesting coffee depends on various factors such as the variety of coffee, environmental conditions, and cultivation practices. Typically, Arabica coffee takes about 3 to 5 years after planting to produce a significant yield, while Robusta coffee may start yielding in about 2 to 3 years. After maturity, coffee plants produce cherries continuously throughout the year, and harvesting is usually done in cycles, often multiple times per year.',
        'Environment':{
            'Rainfall':'Coffee plants prefer consistent rainfall throughout the year, ideally ranging from 1500 mm to 2500 mm annually. However, a well-distributed rainfall pattern is crucial, with no prolonged dry periods or excessive rainfall during flowering and fruit development stages.',
            'Temperatue':'Coffee plants thrive in moderate temperatures, with an optimal range between 15°C to 25°C (59°F to 77°F). Extreme temperatures, especially frost, can damage the plants.',
            'Humidity':'Coffee plants require high humidity levels, ideally between 70% to 80%, especially during flowering and fruit development stages. However, they should also have good air circulation to prevent fungal diseases.',
        },
        'Soil':{
            'Nitrogen':'Coffee plants require a significant amount of nitrogen for healthy growth and fruit development. The soil should ideally have nitrogen levels ranging from 1.5% to 2.5%.',
            'Phoshorous':'Phosphorus is essential for root development and flowering. The ideal soil phosphorus level for coffee cultivation is between 0.20% to 0.40%.',
            'Potassiun':'Potassium plays a crucial role in fruit development and overall plant health. The soil should have potassium levels ranging from 2.0 meq/100g to 3.0 meq/100g.',
            'ph':'Coffee plants prefer slightly acidic to neutral soil pH levels, ideally between 6.0 to 6.5.',
        },
        'Cultivate':{
            'Site selection': 'Choose a site with well-drained soil, preferably with slopes to prevent waterlogging. Ensure the site receives adequate sunlight and has protection from strong winds.',
            'Land preparation': 'Clear the land of weeds and debris. Incorporate organic matter into the soil to improve fertility and structure.',
            'Planting': 'Coffee can be propagated from seeds or cuttings. Plant seeds or seedlings at a spacing of about 2 to 4 meters apart.',
            'Management': 'Provide regular watering, especially during dry periods, and mulch around the base of the plants to conserve moisture and suppress weeds. Prune the plants regularly to maintain shape and facilitate harvesting.',
            'Fertilization': 'Based on soil tests, apply fertilizers containing nitrogen, phosphorus, and potassium as needed. Organic fertilizers such as compost can also be used.',
            'Pest and disease control': 'Monitor the plants regularly for pests and diseases, and take appropriate measures such as the application of biopesticides or cultural practices to control them.',
            'Harvesting': 'Harvest ripe coffee cherries selectively by hand-picking. Cherries are typically harvested when they turn bright red. The harvesting process may be repeated several times throughout the year as cherries ripen at different times.',
            'Processing': 'Process the harvested cherries to extract the coffee beans. This may involve wet or dry processing methods, depending on the desired flavor profile and local practices.',
            'Drying and curing': 'Dry the beans thoroughly to reduce moisture content and prevent mold growth. Once dried, the beans are cured to develop their flavor further before storage and export.'

        }   
    },
    'Cotton':{
        'Duration':'Cotton is typically harvested about 5 to 6 months after planting. However, the exact duration can vary depending on the specific variety of cotton grown and local environmental conditions.',
        'Environment':{
            'Rainfall':'Cotton requires adequate water during its growing period, with an average rainfall ranging from 600 to 1000 mm annually. However, it is also grown in areas with irrigation facilities.',
            'Temperatue':'Cotton thrives in warm temperatures, ideally between 21°C to 30°C during the growing season.',
            'Humidity':'Cotton prefers moderate to high humidity levels, typically around 60% to 80%.',
        },
        'Soil':{
            'Nitrogen':'Cotton requires a significant amount of nitrogen for healthy growth and development. The recommended nitrogen level in soil for cotton cultivation is around 100 to 120 kg/ha.',
            'Phoshorous':'Phosphorus is essential for root development and flowering. The recommended phosphorus level in soil for cotton cultivation is around 40 to 60 kg/ha.',
            'Potassiun':'Potassium is important for overall plant health and disease resistance. The recommended potassium level in soil for cotton cultivation is around 60 to 80 kg/ha.',
            'ph':'Cotton grows best in slightly acidic to neutral soils, with a pH range of 5.5 to 7.5.',
        },
        'Cultivate':{
            'Land Preparation': 'Prepare the land by plowing and leveling to ensure good soil tilth.',
            'Seed Selection': 'Choose high-quality cotton seeds from reliable sources.',
            'Planting': 'Plant cotton seeds at the appropriate spacing, typically in rows, either manually or using mechanized seed drills.',
            'Irrigation': 'Provide sufficient water during the growing season, especially during periods of drought or when rainfall is insufficient.',
            'Fertilization': 'Apply fertilizers according to soil test results and crop requirements, ensuring adequate levels of nitrogen, phosphorus, and potassium.',
            'Weed Control': 'Manage weeds through mechanical methods or herbicide application to prevent competition with cotton plants.',
            'Pest and Disease Management': 'Monitor for pests and diseases regularly, and take appropriate measures such as spraying pesticides or adopting integrated pest management strategies.',
            'Harvesting': 'Harvest cotton when the bolls have matured and burst open, revealing the fluffy cotton fibers inside. This typically occurs 5 to 6 months after planting. Use mechanical cotton pickers or hand-pick depending on the scale of cultivation.',
            'Ginning': 'After harvesting, the cotton is processed through a cotton gin to separate the seeds from the fibers.',
            'Marketing': 'Market the harvested cotton to textile mills or other buyers for further processing and use.'

        }
    },
    'Grapes':{
        'Duration':'The duration for harvesting grapes depends on the variety cultivated and the environmental conditions. Generally, grapes can be harvested anywhere from 3 to 6 months after planting, with some varieties taking longer. However, for wine grapes, it may take up to 5 years for the vines to reach full production potential.',
        'Environment':{
            'Rainfall':'Grapes require moderate rainfall during the growing season. Generally, a range of 600-800 mm annually is considered optimal. Excessive rainfall can lead to diseases like mildew and rot.',
            'Temperatue':'Grapes thrive in temperate climates. The ideal temperature range for grape cultivation is between 15°C to 35°C during the growing season. However, some varieties can tolerate colder temperatures during dormancy.',
            'Humidity':'Grapes prefer moderate humidity levels ranging from 50% to 70%. High humidity can increase the risk of fungal diseases.',
        },
        'Soil':{
            'Nitrogen':'Grapes require moderate levels of nitrogen for healthy growth. The optimal range is between 50-100 kg/ha, but this can vary depending on soil type and grape variety.',
            'Phoshorous':'Phosphorus is essential for root development and fruit production. The optimal range for phosphorus in grape cultivation is between 20-40 kg/ha.',
            'Potassiun':'Potassium is crucial for overall plant health, disease resistance, and fruit quality. The recommended range for potassium in grape cultivation is between 100-200 kg/ha.',
            'ph':'Grapes prefer slightly acidic to neutral soil with a pH range of 6.0 to 7.0.',
        },
        'Cultivate':{
            'Site selection': 'Choose a site with well-drained soil, adequate sunlight, and good air circulation. Avoid low-lying areas prone to frost and waterlogging.',
            'Soil preparation': 'Prepare the soil by plowing and incorporating organic matter like compost or manure to improve soil fertility and structure.',
            'Planting': 'Plant grapevines in rows with proper spacing according to the variety being cultivated. Set up support structures such as trellises or arbors to train the vines.',
            'Irrigation': 'Provide regular irrigation, especially during dry periods, to ensure adequate moisture for plant growth and fruit development. Drip irrigation or soaker hoses are commonly used to deliver water directly to the roots.',
            'Fertilization': 'Apply fertilizers based on soil test results to meet the nutrient requirements of the grapevines. Nitrogen, phosphorus, and potassium fertilizers can be applied as needed throughout the growing season.',
            'Pruning': 'Prune grapevines during the dormant season to remove old wood, improve air circulation, and promote new growth. Pruning also helps manage vine vigor and fruit yield.',
            'Pest and disease management': 'Monitor the vineyard regularly for pests and diseases. Implement integrated pest management (IPM) practices, including cultural, biological, and chemical control methods as necessary.',
            'Harvesting': 'Harvest grapes when they reach the desired maturity level based on sugar content (Brix), acidity, and flavor. Grapes can be harvested by hand or using mechanical harvesters, depending on the scale of cultivation and vineyard layout.'
        }

    },
    'Jute':{
        'Duration':'Jute is typically harvested within 120 to 150 days after sowing, depending on the variety and environmental conditions.',
        'Environment':{
            'Rainfall':'Jute requires high rainfall, preferably around 1500-2000 mm evenly distributed throughout the growing season.',
            'Temperatue':'ute grows well in warm and humid conditions with temperatures ranging between 25°C to 35°C.',
            'Humidity':'High humidity levels, around 80% or more, are favorable for jute cultivation.',
        },
        'Soil':{
            'Nitrogen':'Jute requires a good amount of nitrogen for healthy growth. It is a heavy feeder of nitrogen.',
            'Phoshorous':'Moderate levels of phosphorus are required for jute cultivation.',
            'Potassiun':'Potassium is also essential for jute plants, especially during the flowering and fruiting stages.',
            'ph':'pH of soil: Jute grows well in slightly acidic to neutral soil with a pH range of 6.0 to 7.2.',
        },
        'Cultivate':{
            'Land preparation': 'Prepare the land by plowing and harrowing to make the soil loose and weed-free.',
            'Seed selection': 'Select high-quality jute seeds for sowing.',
            'Sowing': 'Sow the seeds directly into well-prepared soil at a depth of about 2-3 cm. The spacing between rows should be around 15-20 cm.',
            'Irrigation': 'Ensure adequate moisture throughout the growing period, especially during the initial stages of growth.',
            'Weed control': 'Keep the field free from weeds by manual weeding or using appropriate herbicides.',
            'Fertilization': 'Apply organic or chemical fertilizers based on soil nutrient deficiencies. Nitrogen-rich fertilizers are particularly important.',
            'Pest and disease management': 'Monitor the crop regularly for any signs of pests or diseases and take appropriate measures for control.',
            'Harvesting': 'Harvest jute when the plants are mature and the lower leaves start to turn yellow. Cut the plants close to the ground level, leaving about 2-3 cm stubs. Bundles of harvested jute plants are then soaked in water to facilitate stripping of the fibers from the stem.',
            'Fiber extraction': 'After soaking, the outer stem is stripped to extract jute fibers. These fibers are then washed, dried, and processed further for various uses.'

        }
    },
    'Kidneybeans':{
        'Duration':'Duration for harvesting: Kidney beans typically take about 90 to 120 days from planting to harvesting. However, this can vary depending on the specific variety and environmental conditions.',
        'Environment':{
            'Rainfall':'Kidney beans require adequate moisture, with an optimal rainfall range of 400-600 mm during the growing season. However, they are also sensitive to excessive moisture, so well-drained soil is important.',
            'Temperatue':'Kidney beans thrive in warm temperatures. The optimal temperature range for growth is between 18°C to 24°C (65°F to 75°F). Frost can damage the plants, so they should be planted after the last frost date in your region.',
            'Humidity':'Kidney beans prefer moderate humidity levels. While they can tolerate some humidity, excessively damp conditions can lead to diseases such as mold and mildew.',
        },
        'Soil':{
            'Nitrogen':'Kidney beans are nitrogen-fixing plants, meaning they can take nitrogen from the atmosphere and convert it into a form that can be used by the plant. However, they still benefit from nitrogen-rich soil, especially during the early stages of growth. A soil nitrogen level of around 50-100 kg/ha is considered adequate.',
            'Phoshorous':'Phosphorus is essential for root development and overall plant growth. Kidney beans perform best in soils with moderate to high levels of phosphorus. A soil phosphorus level of 20-40 ppm (parts per million) is recommended.',
            'Potassiun':'Potassium is important for flower and fruit development in kidney beans. Soils should have sufficient potassium levels, ideally around 200-300 ppm.',
            'ph':'Kidney beans prefer slightly acidic to neutral soil pH, typically between 6.0 to 7.0.',
        },
        'Cultivate':{
            'Site selection': 'Choose a well-drained area with plenty of sunlight for planting kidney beans.',
            'Soil preparation': 'Prepare the soil by loosening it to a depth of about 6-8 inches and remove any weeds or debris.',
            'Planting': 'Plant kidney bean seeds directly into the soil after the last frost date, spacing them about 3-6 inches apart in rows that are 18-24 inches apart. Plant the seeds about 1-2 inches deep.',
            'Watering': 'Keep the soil consistently moist but not waterlogged, especially during flowering and pod development.',
            'Fertilization': 'If the soil is lacking in nutrients, you can apply a balanced fertilizer before planting, but be cautious with nitrogen as kidney beans can fix their own nitrogen.',
            'Weed control': 'Keep the area around the kidney bean plants free of weeds to reduce competition for nutrients and water.',
            'Harvesting': 'Harvest kidney beans when the pods are fully mature and dry. This is typically around 90 to 120 days after planting. Pull up the entire plant and hang it in a dry, well-ventilated area to dry further before removing the beans from the pods.'
        }
    },
    'Lentils':{
        'Duration':'Lentils typically take about 90 to 120 days to mature and be ready for harvest after planting, depending on the variety and environmental conditions.',
        'Environment':{
            'Rainfall':'Lentils prefer well-distributed rainfall during their growing season. The ideal range is between 300 to 600 mm (12 to 24 inches) annually. However, lentils can also tolerate drought conditions to some extent.',
            'Temperatue':'Lentils grow best in moderate temperatures. The optimal temperature range for lentil cultivation is between 15°C to 25°C (59°F to 77°F). They can tolerate temperatures as low as 5°C (41°F) and as high as 35°C (95°F) during their growing season.',
            'Humidity':'Lentils generally prefer lower humidity levels during their growth period. They can thrive in areas with moderate humidity, but excessive humidity can lead to fungal diseases.',
        },
        'Soil':{
            'Nitrogen':'Lentils are nitrogen-fixing legumes, meaning they have the ability to fix atmospheric nitrogen into the soil with the help of symbiotic bacteria. However, they still benefit from nitrogen-rich soils. A soil nitrogen level of around 40 to 80 kg/ha is considered adequate for lentil cultivation.',
            'Phoshorous':'Lentils require moderate levels of phosphorus for optimal growth. A soil phosphorus level of 15 to 30 kg/ha is suitable for lentil cultivation.',
            'Potassiun':'Lentils have moderate potassium requirements. A soil potassium level of 25 to 50 kg/ha is adequate for lentil cultivation.',
            'ph':'Lentils prefer slightly acidic to neutral soils with a pH range between 6.0 to 7.5.',
        },
        'Cultivate':{
            'Site selection': 'Choose a well-drained field with good sunlight exposure for lentil cultivation. Avoid waterlogged or compacted soils.',
            'Seed selection': "Select high-quality lentil seeds of suitable varieties based on your region's climate and soil conditions.",
            'Soil preparation': 'Prepare the soil by plowing and harrowing to ensure a fine seedbed. Lentils prefer loamy or sandy loam soils with good fertility.',
            'Seed sowing': 'Sow lentil seeds directly into the prepared soil at a depth of around 3 to 5 cm (1.2 to 2 inches). The optimal spacing between rows is about 30 to 40 cm (12 to 16 inches).',
            'Fertilization': 'Lentils generally require little to no fertilizer if the soil is adequately fertile. However, if soil tests indicate deficiencies, you can apply balanced fertilizers containing nitrogen, phosphorus, and potassium before sowing.',
            'Irrigation': 'Lentils require regular but moderate irrigation, especially during flowering and pod development stages. Avoid overwatering, as lentils are susceptible to waterlogging.',
            'Weed control': 'Keep the field weed-free through manual weeding or use of herbicides, especially during the early growth stages of lentils.',
            'Disease and pest management': 'Monitor the crop regularly for signs of diseases and pests. Practice crop rotation and use disease-resistant varieties to minimize risks. Integrated pest management (IPM) strategies can help control pests effectively.',
            'Harvesting': 'Lentils are ready for harvest when the pods turn yellow or brown and the seeds are hard. Use a combine harvester or hand-pick the pods, depending on the scale of cultivation. Allow the harvested lentils to dry thoroughly before storage.',
            'Post-harvest management': 'Clean and store the lentils properly in well-ventilated containers to prevent moisture buildup and fungal growth.'   
        }
    },
    'Maize':{
        'Duration':'The harvesting duration for maize typically ranges from 60 to 120 days after planting, depending on the variety and environmental conditions.',
        'Environment':{
            'Rainfall':'Maize requires well-distributed rainfall during its growing period. Generally, it needs around 500-800 mm of rainfall throughout the growing season. However, adequate moisture during the critical growth stages like germination, flowering, and grain filling is essential.',
            'Temperatue':'Maize grows well in a temperature range of 20°C to 30°C during the growing season. It is sensitive to frost and requires warm temperatures for optimal growth.',
            'Humidity':'Maize can tolerate a wide range of humidity levels but generally thrives in moderate humidity conditions. Relative humidity levels of 60-70% are considered favorable for maize growth.',
        },
        'Soil':{
            'Nitrogen':'Maize requires a significant amount of nitrogen for optimal growth. The recommended nitrogen application varies depending on soil type and other factors but typically ranges from 100 to 200 kg/ha.',
            'Phoshorous':'Maize requires phosphorus for root development and early growth stages. Phosphorus application rates vary but commonly range from 30 to 60 kg/ha.',
            'Potassiun':' Potassium is essential for overall plant health and development, including stress tolerance and disease resistance. The recommended potassium application for maize is typically between 50 to 100 kg/ha.',
            'ph':'Maize grows best in slightly acidic to neutral soils with a pH range of 6.0 to 7.5. Soil pH outside this range may affect nutrient availability and overall crop performance.',
        },
        'Cultivate':{
            'Land preparation': 'Prepare the land by plowing and harrowing to create a fine seedbed. Remove weeds and debris to ensure optimal growing conditions.',
            'Seed selection': 'Choose high-quality maize seeds of a suitable variety based on your local climate, soil type, and intended use (e.g., for grain production or silage).',
            'Planting': 'Plant maize seeds at the recommended spacing and depth. Generally, maize is planted at a depth of 3-5 cm and spacing of 20-30 cm between plants and 60-90 cm between rows.',
            'Fertilization': 'Apply fertilizers based on soil test results and nutrient requirements. Incorporate fertilizers into the soil during land preparation or apply them in bands near the seed at planting.',
            'Irrigation': 'Provide adequate irrigation during dry periods, especially during critical growth stages such as germination, flowering, and grain filling.',
            'Weed control': 'Control weeds through mechanical or chemical means to prevent competition for nutrients, water, and light.',
            'Pest and disease management': 'Monitor the crop regularly for pests and diseases and take appropriate measures for control if necessary.',
            'Harvesting': 'Harvest maize when the kernels are fully developed and mature. This is typically indicated by the drying and yellowing of the husks. Use appropriate harvesting equipment to minimize losses and ensure efficient harvesting.'
        }
    },
    'Mango':{
        'Duration':'The duration for harvesting mangoes typically varies depending on the variety of mango and the region in which it is cultivated. However, on average, mango trees start bearing fruits within 3-5 years after planting, and the harvesting season generally spans from March to July, again depending on the variety and location.',
        'Environment':{
            'Rainfall':'Mango trees require a well-distributed rainfall during the growing season. However, they can tolerate drought conditions to some extent. Generally, a rainfall of around 1000-2500 mm per year is suitable for mango cultivation.',
            'Temperatue':' Mangoes thrive in tropical and subtropical climates. The optimum temperature range for mango cultivation is between 24°C to 30°C (75°F to 86°F). Mango trees can tolerate temperatures as high as 48°C (118°F) and as low as 10°C (50°F), but prolonged exposure to extreme temperatures can affect fruit quality and yield.',
            'Humidity':'Mango trees prefer humid conditions during the growing season. A relative humidity of around 60-80% is considered ideal for mango cultivation.',
        },
        'Soil':{
            'Nitrogen':'Mango trees require a good supply of nitrogen for healthy growth and fruit development. The soil should have a nitrogen content of around 0.2% to 0.5%.',
            'Phoshorous':'Phosphorus is essential for root development and flowering in mango trees. The soil should have a phosphorus content of around 0.1% to 0.3%.',
            'Potassiun':' Potassium is important for fruit development and overall plant health. The soil should have a potassium content of around 0.2% to 0.5%.',
            'ph':'Mango trees prefer slightly acidic to neutral soil pH. The ideal pH range for mango cultivation is between 5.5 to 7.5.',
        },
        'Cultivate':{
            'Site Selection': 'Choose a location with well-drained soil and good sunlight exposure for planting mango trees.',
            'Land Preparation': 'Prepare the land by plowing and leveling. Ensure proper drainage to avoid waterlogging.',
            'Variety Selection': "Select suitable mango varieties based on your region's climatic conditions and market demand.",
            'Planting': 'Plant mango trees during the rainy season or early summer. Dig a hole large enough to accommodate the root ball of the sapling. Space the trees at least 10-15 meters apart to allow for proper growth.',
            'Irrigation': 'Provide regular irrigation, especially during the dry season and the first few years after planting. Mango trees require sufficient moisture for healthy growth and fruit development.',
            'Fertilization': "Apply organic or chemical fertilizers containing nitrogen, phosphorus, and potassium according to soil test results and the tree's growth stage.",
            'Pruning': 'Prune mango trees regularly to maintain shape, remove dead or diseased branches, and promote air circulation within the canopy.',
            'Pest and Disease Management': 'Monitor for pests and diseases regularly and take appropriate measures such as spraying pesticides or adopting cultural practices to control them.',
            'Harvesting': 'Harvest mango fruits when they reach their mature size, color, and flavor. Use pruning shears or hand-pick the fruits carefully to avoid damage.',
            'Post-Harvest Handling': 'Handle harvested mangoes gently to prevent bruising. Sort and pack them properly for storage or transportation to markets.'

        }
    },
    'Mothbeans':{
        'Duration':'Mothbeans typically have a relatively short duration for harvesting compared to other crops. They are usually ready for harvest within 60 to 70 days after sowing, depending on the specific variety and environmental conditions.',
        'Environment':{
            'Rainfall':'Mothbeans prefer a moderate amount of rainfall during their growing period. They can tolerate both dry and moist conditions, but excessive rainfall or waterlogging can negatively affect their growth. An average rainfall of 600-800 mm during the growing season is ideal.',
            'Temperatue':'Mothbeans thrive in warm temperatures. The optimum temperature for their growth is between 25°C to 35°C.',
            'Humidity':'Mothbeans prefer moderate humidity levels. High humidity combined with high temperatures can create conditions favorable for diseases, so proper ventilation is important.',
        },
        'Soil':{
            'Nitrogen':'Mothbeans are capable of fixing atmospheric nitrogen with the help of symbiotic bacteria in their root nodules. However, a soil rich in nitrogen can still be beneficial for their growth. Generally, a nitrogen-rich soil or supplemented with organic matter is preferred.',
            'Phoshorous':'Phosphorus is important for root development and overall plant growth. A soil with moderate to high phosphorus content is beneficial for mothbean cultivation.',
            'Potassiun':'Potassium is essential for various physiological processes in plants, including water regulation and disease resistance. Mothbeans require a soil with adequate potassium levels for optimal growth.',
            'ph':'Mothbeans prefer slightly acidic to neutral soil pH ranging from 6.0 to 7.5. Soil pH influences nutrient availability to plants, so maintaining the pH within this range is important for healthy growth.',
        },
        'Cultivate':{
            'Land preparation': 'Prepare the land by plowing and leveling it properly. Remove any weeds and debris.',
            'Seed selection': 'Choose high-quality seeds from a reliable source.',
            'Sowing': 'Sow the seeds directly into the prepared soil at a depth of about 3-5 cm. The spacing between rows should be around 30-45 cm, and between plants within a row should be about 10-15 cm.',
            'Irrigation': 'Provide regular irrigation, especially during the germination and flowering stages. Mothbeans are drought tolerant but require adequate moisture for optimal growth and yield.',
            'Weed control': 'Keep the field free from weeds, either manually or by using appropriate herbicides.',
            'Fertilization': 'If necessary, apply fertilizers based on soil test results to ensure adequate nutrient availability.',
            'Pest and disease management': 'Monitor the crop regularly for any signs of pests or diseases and take appropriate measures for control.',
            'Harvesting': 'Harvest the mature pods when they turn yellowish-brown and the seeds inside are fully developed. This usually occurs around 60 to 70 days after sowing. Cut the plants close to the ground and thresh the pods to separate the seeds.'

        }
    },
    'Mungbean':{
        'Duration':'Mungbean typically takes about 60-90 days to reach maturity and be ready for harvest after planting, depending on the variety and environmental conditions.',
        'Environment':{
            'Rainfall':'Mungbeans require adequate moisture for germination and early growth. They are sensitive to waterlogging but can tolerate drought conditions to some extent. Generally, they require around 400-600 mm of well-distributed rainfall during the growing season.',
            'Temperatue':'Mungbeans prefer warm temperatures for optimal growth. The ideal temperature range for mungbean cultivation is between 25°C to 35°C. They can tolerate temperatures up to 40°C but are sensitive to frost.',
            'Humidity':'Mungbeans prefer moderate humidity levels during their growth period. Humidity levels between 60% to 80% are considered suitable.',
        },
        'Soil':{
            'Nitrogen':'Mungbeans are nitrogen-fixing legumes, meaning they have the ability to fix atmospheric nitrogen with the help of symbiotic bacteria in their root nodules. However, they still benefit from nitrogen-rich soils. Soil nitrogen content should ideally be around 30-40 kg/ha.',
            'Phoshorous':'Adequate phosphorus is essential for mungbean growth and development, especially during the early stages. Phosphorus levels in the soil should be maintained between 15-30 kg/ha.',
            'Potassiun':'Potassium is important for overall plant health and stress tolerance. Soil potassium levels should be maintained between 80-120 kg/ha.',
            'ph':'Mungbeans prefer slightly acidic to neutral soils with a pH range of 6.0 to 7.5.',
        },
        'Cultivate':{
            'Land Preparation': 'Prepare the land by plowing and harrowing to achieve a fine tilth. Ensure good drainage to prevent waterlogging.',
            'Seed Selection': 'Select healthy, disease-free seeds for planting. Treat seeds with appropriate fungicides or bactericides to protect against seed-borne diseases.',
            'Planting': 'Plant mungbean seeds directly into the prepared seedbeds or rows at a depth of about 3-5 cm. Row spacing should be around 30-45 cm, depending on the variety.',
            'Irrigation': 'Provide irrigation immediately after planting to ensure good germination. Subsequent irrigation should be done as needed based on soil moisture levels and weather conditions.',
            'Weed Control': 'Keep the field free from weeds, especially during the initial growth stages, to reduce competition for nutrients and water.',
            'Fertilization': 'Based on soil test results, apply necessary fertilizers, especially phosphorus and potassium, before planting. Mungbeans generally require less nitrogen due to their nitrogen-fixing ability.',
            'Pest and Disease Management': 'Monitor the crop regularly for pest and disease outbreaks. Use appropriate pesticides or cultural practices to manage pests and diseases effectively.',
            'Harvesting': 'Mungbeans are ready for harvest when the pods turn yellowish-brown and the seeds inside are fully developed. Harvest the crop by handpicking the pods or by using mechanical harvesters. Dry the harvested pods to reduce moisture content before storage.',
            'Post-harvest Management': 'Clean and dry the harvested seeds properly to prevent spoilage during storage. Store the seeds in a cool, dry place to maintain quality and viability for future planting.'
        }
    },
    'Muskmelon':{
        'Duration':'Muskmelon typically takes around 70 to 90 days from planting to harvesting, depending on the variety and growing conditions.',
        'Environment':{
            'Rainfall':'Muskmelons require moderate water supply. Adequate irrigation is essential, especially during the fruiting stage. An average of 18-25 inches (45-65 cm) of water throughout the growing season is recommended.',
            'Temperatue':'Muskmelons thrive in warm temperatures. The optimum temperature for growth is between 70°F to 90°F (21°C to 32°C) during the day and not lower than 60°F (15°C) at night.',
            'Humidity':' Muskmelons prefer moderate humidity levels ranging from 60% to 80%.',
        },
        'Soil':{
            'Nitrogen':'Muskmelons require a moderate to high level of nitrogen. A soil with nitrogen content of around 50-100 pounds per acre is suitable.',
            'Phoshorous':'Adequate phosphorus is essential for root development and fruit formation. Phosphorus levels should be around 50-80 pounds per acre.',
            'Potassiun':'Potassium is crucial for overall plant health and fruit development. A soil with potassium content ranging from 100-150 pounds per acre is ideal.',
            'ph':'Muskmelons grow best in slightly acidic to neutral soil with a pH range of 6.0 to 7.0.',
        },
        'Cultivate':{
            'Site Selection': 'Choose a sunny location with well-drained soil. Muskmelons prefer sandy loam soil.',
            'Soil Preparation': 'Prepare the soil by tilling to a depth of 12-18 inches and incorporate organic matter such as compost to improve soil structure and fertility.',
            'Planting': 'Plant muskmelon seeds directly into the soil after the last frost date in your area. Sow seeds 1 inch deep and 18-24 inches apart in rows spaced 4-6 feet apart.',
            'Watering': 'Keep the soil consistently moist, especially during flowering and fruiting stages. Avoid overhead watering to prevent fungal diseases.',
            'Fertilization': 'Apply a balanced fertilizer with higher nitrogen content at planting time and side-dress with additional fertilizer containing phosphorus and potassium when the vines start to run.',
            'Mulching': 'Mulch around the plants to conserve moisture, suppress weeds, and maintain even soil temperature.',
            'Support': 'Provide support for the growing vines by using trellises or allowing them to sprawl on the ground.',
            'Pest and Disease Control': 'Monitor for pests such as aphids, cucumber beetles, and powdery mildew. Control measures may include insecticidal sprays and fungicides as necessary.',
            'Harvesting': 'Harvest muskmelons when they reach full maturity, indicated by a sweet aroma, golden color under the netting, and a slight softening of the blossom end. Cut the fruit from the vine with a sharp knife, leaving a short stem attached.'
        }
    },
    'Oranges':{
        'Duration':'Oranges typically take around 8-14 months from flowering to harvesting, depending on the variety and growing conditions.',
        'Environment':{
            'Rainfall':'Oranges require moderate rainfall, ideally between 900-1200 mm annually. However, they can tolerate drought conditions to some extent.',
            'Temperatue':'Oranges thrive in warm to hot climates. The optimum temperature for growth is between 15°C to 30°C.',
            'Humidity':' Oranges prefer moderate to high humidity levels, ideally around 50-70%.',
        },
        'Soil':{
            'Nitrogen':'Oranges require nitrogen for healthy foliage and fruit development. The recommended nitrogen content in soil varies but typically ranges from 100-200 kg/ha.',
            'Phoshorous':'Phosphorus is essential for root development and fruit quality. The recommended phosphorus content in soil is around 30-60 kg/ha.',
            'Potassiun':'Potassium is crucial for overall plant growth and fruit development. The recommended potassium content in soil ranges from 100-200 kg/ha.',
            'ph':'Oranges prefer slightly acidic to neutral soil pH, ideally between 6.0 to 7.5.',
        },
        'Cultivate':{
            'Site Selection': 'Choose a site with well-drained soil, adequate sunlight exposure, and protection from strong winds.',
            'Soil Preparation': 'Test the soil to determine its pH and nutrient levels. Amend the soil as needed to ensure proper drainage and nutrient availability.',
            'Planting': "Oranges can be propagated from seeds, cuttings, or grafting onto rootstocks. Plant the trees during the appropriate season, spacing them according to the variety's requirements.",
            'Irrigation': 'Provide regular irrigation, especially during dry periods, ensuring that the soil remains moist but not waterlogged.',
            'Fertilization': 'Apply fertilizers containing nitrogen, phosphorus, and potassium according to soil test results and the specific needs of the orange trees. Fertilize in split doses during the growing season.',
            'Pruning': 'Prune the trees to remove dead or diseased branches, promote airflow, and shape the canopy for optimal fruit production.',
            'Pest and Disease Management': 'Monitor the trees regularly for pests and diseases, and take appropriate measures such as biological controls or chemical treatments if necessary.',
            'Harvesting': 'Oranges are typically harvested when they reach full coloration and size, depending on the variety. Use pruning shears to carefully cut the fruit from the tree to avoid damage.',
            'Post-Harvest Care': 'Handle the harvested fruit gently to prevent bruising and store them in a cool, dry place.'
        }
    },
    'Papaya':{
        'Duration':'Papayas typically take about 6 to 9 months from planting to harvesting. However, this can vary depending on the variety of papaya, environmental conditions, and agricultural practices.',
        'Environment':{
            'Rainfall':"Papayas require adequate water supply, especially during the growing season. The optimal rainfall for papaya cultivation is around 1200-1500 mm per year. However, it's important to ensure good drainage to prevent waterlogging.",
            'Temperatue':'Papayas thrive in warm temperatures. The optimal temperature range for papaya cultivation is between 25°C to 30°C (77°F to 86°F). Extreme temperatures, especially frost, can harm papaya plants.',
            'Humidity':'Papayas prefer moderate to high humidity levels. Humidity levels around 60-80% are ideal for papaya cultivation.',
        },
        'Soil':{
            'Nitrogen':'Papaya plants require a significant amount of nitrogen for healthy growth and fruit production. Optimal nitrogen levels in the soil should be around 100-150 kg/ha.',
            'Phoshorous':'Phosphorus is essential for root development and overall plant growth. The recommended phosphorus level in the soil for papaya cultivation is around 50-100 kg/ha.',
            'Potassiun':"Potassium helps in fruit development and improves the plant's resistance to diseases and stress. The ideal potassium level in the soil for papaya cultivation is around 50-100 kg/ha.",
            'ph':'Papayas prefer slightly acidic to neutral soils with a pH range of 6.0 to 7.0. Soil pH outside this range may affect nutrient availability and plant growth.',
        },
        'Cultivate':{
            'Site Selection': 'Choose a site with well-drained soil and ample sunlight exposure. Avoid areas prone to waterlogging or frost.',
            'Land Preparation': 'Prepare the land by plowing and harrowing to loosen the soil. Incorporate organic matter such as compost or well-rotted manure to improve soil fertility and structure.',
            'Planting': 'Papayas can be propagated from seeds or seedlings. Plant seeds directly in the field or transplant seedlings into prepared beds. Maintain proper spacing between plants, usually around 2-3 meters apart.',
            'Irrigation': 'Provide regular irrigation, especially during dry periods, to ensure adequate soil moisture. Drip irrigation or sprinkler systems can be used for efficient water distribution.',
            'Fertilization': 'Apply fertilizers containing nitrogen, phosphorus, and potassium according to soil test recommendations or general guidelines. Split the fertilizer application throughout the growing season.',
            'Weed Control': 'Keep the area around papaya plants weed-free to reduce competition for nutrients and water. Manual weeding or mulching can help suppress weed growth.',
            'Pest and Disease Management': 'Monitor papaya plants regularly for pests and diseases such as papaya ringspot virus, papaya mealybug, and powdery mildew. Use appropriate cultural practices and organic or chemical control methods as needed.',
            'Support and Pruning': 'Provide support for papaya plants, especially during heavy fruiting, to prevent them from toppling over. Prune overcrowded or diseased branches to maintain plant vigor and improve air circulation.',
            'Harvesting': 'Papayas are typically ready for harvest 6 to 9 months after planting, depending on the variety. Harvest fruits when they reach mature size and firmness, usually with a slight yellowish tint. Cut fruits from the plant using a sharp knife or pruning shears, leaving a short stem attached.',
            'Post-Harvest Handling': 'Handle harvested papayas with care to avoid bruising or damage. Store fruits in a cool, dry place or refrigerate them for longer shelf life.'
        }
    },
    'Pigeonpeas':{
        'Duration':'Pigeonpeas typically have a harvesting duration of about 150 to 180 days after sowing, depending on the variety and growing conditions.',
        'Environment':{
            'Rainfall':'Pigeonpeas require well-distributed rainfall ranging from 600 to 1000 mm annually. They are generally drought-tolerant but require sufficient moisture during the flowering and pod development stages.',
            'Temperatue':'Pigeonpeas thrive in warm to hot temperatures, with an optimal range between 20°C to 30°C.',
            'Humidity':'Pigeonpeas prefer moderate humidity levels, ideally around 50% to 70%.',
        },
        'Soil':{
            'Nitrogen':'Pigeonpeas are known for their ability to fix atmospheric nitrogen through symbiotic relationships with nitrogen-fixing bacteria in their root nodules. However, they still benefit from nitrogen-rich soils.',
            'Phoshorous':'Pigeonpeas require moderate levels of phosphorus for optimal growth and yield.',
            'Potassiun':'Potassium is essential for pigeonpeas, particularly during flowering and pod development stages.',
            'ph':'Pigeonpeas prefer slightly acidic to neutral soils with a pH range between 6.0 to 7.0.',
        },
        'Cultivate':{
            'Site Selection': 'Choose a well-drained field with good sunlight exposure.',
            'Land Preparation': 'Plow the field to a fine tilth to ensure good soil aeration and drainage.',
            'Seed Selection': 'Choose healthy and disease-free seeds from a reliable source.',
            'Sowing': 'Sow the seeds at a depth of about 3-5 cm and spacing of 60-90 cm between rows, depending on the variety.',
            'Irrigation': 'Provide irrigation immediately after sowing and ensure adequate moisture throughout the growing period, especially during flowering and pod development stages.',
            'Weed Control': 'Keep the field weed-free through regular weeding or by using herbicides, particularly during the initial growth stages.',
            'Fertilization': 'Apply fertilizers based on soil test results, focusing on nitrogen, phosphorus, and potassium requirements.',
            'Pest and Disease Management': 'Monitor the crop regularly for pests and diseases, and take appropriate measures for control if necessary.',
            'Support': 'Provide support such as staking for taller varieties to prevent lodging.',
            'Harvesting': 'Harvest the matured pods when they turn brown and dry, usually 150 to 180 days after sowing. Cut the entire plant and allow it to dry further before threshing to separate the seeds.',
            'Post-harvest Handling': 'Clean, dry, and store the harvested seeds properly to maintain quality and prevent pest infestation.'
        }
    },
    'Pomegranate':{
        'Duration':'Pomegranate trees typically start bearing fruits within 2 to 3 years after planting, but full commercial production usually begins around the 4th or 5th year. Once the trees start producing fruit, harvesting typically occurs from late summer to early fall, depending on the variety and location.',
        'Environment':{
            'Rainfall':'Pomegranate trees prefer dry climates with minimal rainfall during the growing season. They can tolerate drought conditions well, but irrigation may be necessary during prolonged dry spells. Ideal annual rainfall ranges from 500 to 1000 millimeters.',
            'Temperatue':'Pomegranates thrive in hot climates and can tolerate temperatures ranging from 40°F (4°C) to 100°F (38°C) during the growing season. However, they require a chilling period of 150 to 200 hours below 45°F (7°C) during the dormant season for proper fruit set.',
            'Humidity':'Pomegranate trees prefer low humidity levels. They are adapted to arid and semi-arid climates and can withstand dry air.',
        },
        'Soil':{
            'Nitrogen':'Pomegranate trees have moderate nitrogen requirements. Soil with nitrogen levels ranging from 100 to 150 ppm is suitable for optimal growth.',
            'Phoshorous':'Pomegranates require phosphorus for root development and fruit production. A soil phosphorus level of 20 to 40 ppm is ideal.',
            'Potassiun':'Potassium is essential for fruit quality and overall tree health. Pomegranate trees thrive in soils with potassium levels ranging from 150 to 300 ppm.',
            'ph':'Pomegranates prefer slightly acidic to neutral soil pH, ideally between 5.5 and 7.0.',
        },
        'Cultivate':{
            'Site selection': 'Choose a well-drained site with full sun exposure for planting pomegranate trees. Avoid areas prone to waterlogging.',
            'Soil preparation': 'Prepare the soil by incorporating organic matter such as compost or well-rotted manure. Ensure the soil pH is within the optimal range.',
            'Planting': 'Plant pomegranate trees during the dormant season (late winter to early spring). Dig a hole slightly larger than the root ball and set the tree at the same depth as it was in the nursery. Space trees 12 to 15 feet apart in rows.',
            'Irrigation': 'Provide regular irrigation during the establishment period, then gradually reduce watering once the trees are established. Pomegranate trees are drought-tolerant but benefit from occasional deep watering during dry spells.',
            'Fertilization': 'Apply nitrogen, phosphorus, and potassium fertilizers based on soil test results and tree requirements. Split applications may be necessary during the growing season.',
            'Pruning': 'Prune pomegranate trees to remove dead or diseased branches and shape the canopy for optimal sunlight penetration and air circulation. Pruning is typically done during the dormant season.',
            'Pest and disease management': 'Monitor trees regularly for pests such as aphids, mealybugs, and fruit borers, as well as diseases like fungal infections and bacterial blight. Use cultural practices and, if necessary, apply appropriate pesticides or fungicides to manage pests and diseases.',
            'Harvesting': 'Harvest pomegranates when they reach full maturity, indicated by their color and size. Cut the fruit from the tree rather than pulling it to avoid damaging the branches. Store harvested fruits in a cool, dry place.'
        }
    },
    'Rice':{
        'Duration':'The harvesting duration for rice depends on the variety cultivated and the growing conditions. Typically, it takes around 3 to 6 months from planting to harvesting, with some varieties taking longer.',
        'Environment':{
            'Rainfall':'Rice is a water-intensive crop and requires significant amounts of water for cultivation. The optimal rainfall for rice cultivation varies depending on the stage of growth, but generally, it requires around 1500-2500 mm of rainfall during the growing season.',
            'Temperatue':'Rice grows best in warm temperatures. The optimal temperature range for rice cultivation is between 20°C to 35°C (68°F to 95°F).',
            'Humidity':'Rice cultivation requires high humidity levels, especially during the flowering and grain-filling stages. Humidity levels of around 70-90% are desirable for optimal growth.',
        },
        'Soil':{
            'Nitrogen':'Rice requires a significant amount of nitrogen for healthy growth, particularly during the vegetative stage. Soil nitrogen levels should ideally be in the range of 80-120 kg/ha.',
            'Phoshorous':'Phosphorus is essential for root development and overall plant growth. Soil phosphorus levels should be maintained at around 20-40 kg/ha.',
            'Potassiun':'Potassium plays a crucial role in the development of rice plants, especially during the reproductive stage. Soil potassium levels should be in the range of 80-120 kg/ha.',
            'ph':'Rice grows best in slightly acidic to neutral soils with a pH range of 6.0 to 7.5.',
        },
        'Cultivate':{
            'Land Preparation': 'Prepare the field by plowing, leveling, and puddling the soil to create a suitable environment for rice cultivation.',
            'Seed Selection and Treatment': 'Select high-quality seeds of the desired rice variety and treat them with fungicides or insecticides to prevent diseases and pests.',
            'Planting': 'Plant the seeds either directly into the flooded field or in seedbeds for later transplanting. Planting density depends on the variety and the desired yield.',
            'Water Management': 'Maintain proper water levels in the field throughout the growing season. Rice requires flooded or saturated conditions during most of its growth stages.',
            'Fertilization': 'Apply fertilizers containing nitrogen, phosphorus, and potassium according to soil test results and crop nutrient requirements. Fertilizers can be applied as basal dose, split application, or foliar spray.',
            'Weed Control': 'Control weeds through manual weeding, herbicide application, or integrated weed management practices to prevent competition for nutrients and water.',
            'Pest and Disease Management': 'Monitor the crop regularly for pests and diseases and take appropriate measures such as pesticide application or cultural practices to control them.',
            'Harvesting': 'Harvest the rice when the grains are fully matured and the moisture content is around 20-25%. Harvesting methods include hand harvesting, mechanized harvesting, or using combine harvesters.',
            'Drying and Threshing': 'Dry the harvested rice to reduce moisture content and facilitate threshing. Thresh the rice to separate the grains from the straw.',
            'Storage': 'Store the harvested rice in clean and dry conditions to prevent spoilage from pests, moisture, and mold.'
        }
    },
    'Watermelon':{
        'Duration':'Typically, watermelons take about 80 to 100 days from planting to harvest. However, this can vary depending on the variety of watermelon and environmental conditions.',
        'Environment':{
            'Rainfall':'Watermelons require adequate but well-drained soil and consistent moisture. Ideally, they need around 20-30 inches of rainfall throughout the growing season. However, irrigation may be necessary in regions with insufficient rainfall.',
            'Temperatue':'Watermelons thrive in warm temperatures. The optimal temperature range for watermelon growth is between 70°F to 90°F (21°C to 32°C) during the day and above 50°F (10°C) at night.',
            'Humidity':'Watermelons prefer moderate humidity levels ranging from 60% to 80%.',
        },
        'Soil':{
            'Nitrogen':'Watermelons have a moderate to high nitrogen requirement. Soil should have a nitrogen content of about 50-100 lbs per acre for optimal growth.',
            'Phoshorous':'Adequate phosphorus is crucial for root development and fruit production. Soil should contain approximately 40-80 lbs per acre of phosphorus.',
            'Potassiun':'Potassium helps in fruit development and overall plant health. Soil should have around 100-150 lbs per acre of potassium.',
            'ph':'Watermelons prefer slightly acidic to neutral soil with a pH range of 6.0 to 7.5.',
        },
        'Cultivate':{
            'Site selection': 'Choose a site with well-drained soil and ample sunlight exposure.',
            'Soil preparation': 'Till the soil to a depth of 6-8 inches and incorporate organic matter like compost for improved fertility and drainage.',
            'Planting': 'Sow watermelon seeds directly into the prepared soil or transplant seedlings after the last frost date. Space seeds or seedlings 2-3 feet apart in rows spaced 6-8 feet apart.',
            'Watering': 'Provide consistent moisture, especially during the flowering and fruiting stages. Water deeply and regularly, aiming to keep the soil evenly moist but not waterlogged.',
            'Fertilization': 'Apply fertilizer according to soil test recommendations before planting and side-dress with additional nitrogen and potassium fertilizer during the growing season as needed.',
            'Weed control': 'Keep the area around watermelon plants free from weeds to reduce competition for nutrients and water.',
            'Pest and disease management': 'Monitor plants regularly for signs of pests and diseases and take appropriate measures such as using organic pesticides or practicing crop rotation to prevent infestations.',
            'Support': 'Consider providing support for the developing fruit by using trellises or slings to prevent them from touching the ground and reduce the risk of rot.',
            'Harvesting':'Watermelons are ready for harvest when the tendrils near the stem turn brown, and the underside of the fruit turns creamy yellow. Harvest by cutting the stem with a sharp knife, leaving a few inches attached to the fruit.'

        }

    }
       
}

# %%
import json
with open('allcrop.json', 'w') as f:
    json.dump(crop, f)
# ['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee',
#        'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize',
#        'mango', 'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya',
#        'pigeonpeas', 'pomegranate', 'rice', 'watermelon']

# %%
crop.keys()
# Out:
# dict_keys(['Apple', 'Banana', 'Blackgram', 'Chickpea', 'Coconut', 'Coffee', 'Cotton', 'Grapes', 'Jute', 'Kidneybeans', 'Lentils', 'Maize', 'Mango', 'Mothbeans', 'Mungbean', 'Muskmelon', 'Oranges', 'Papaya', 'Pigeonpeas', 'Pomegranate', 'Rice', 'Watermelon'])

# %%
'Watermelon':{
    'Duration':'Typically, watermelons take about 80 to 100 days from planting to harvest. However, this can vary depending on the variety of watermelon and environmental conditions.',
    'Environment':{
        'Rainfall':'Watermelons require adequate but well-drained soil and consistent moisture. Ideally, they need around 20-30 inches of rainfall throughout the growing season. However, irrigation may be necessary in regions with insufficient rainfall.',
        'Temperatue':'Watermelons thrive in warm temperatures. The optimal temperature range for watermelon growth is between 70°F to 90°F (21°C to 32°C) during the day and above 50°F (10°C) at night.',
        'Humidity':'Watermelons prefer moderate humidity levels ranging from 60% to 80%.',
    },
    'Soil':{
        'Nitrogen':'Watermelons have a moderate to high nitrogen requirement. Soil should have a nitrogen content of about 50-100 lbs per acre for optimal growth.',
        'Phoshorous':'Adequate phosphorus is crucial for root development and fruit production. Soil should contain approximately 40-80 lbs per acre of phosphorus.',
        'Potassiun':'Potassium helps in fruit development and overall plant health. Soil should have around 100-150 lbs per acre of potassium.',
        'ph':'Watermelons prefer slightly acidic to neutral soil with a pH range of 6.0 to 7.5.',
    },
    'Cultivate':{
        'Site selection': 'Choose a site with well-drained soil and ample sunlight exposure.',
        'Soil preparation': 'Till the soil to a depth of 6-8 inches and incorporate organic matter like compost for improved fertility and drainage.',
        'Planting': 'Sow watermelon seeds directly into the prepared soil or transplant seedlings after the last frost date. Space seeds or seedlings 2-3 feet apart in rows spaced 6-8 feet apart.',
        'Watering': 'Provide consistent moisture, especially during the flowering and fruiting stages. Water deeply and regularly, aiming to keep the soil evenly moist but not waterlogged.',
        'Fertilization': 'Apply fertilizer according to soil test recommendations before planting and side-dress with additional nitrogen and potassium fertilizer during the growing season as needed.',
        'Weed control': 'Keep the area around watermelon plants free from weeds to reduce competition for nutrients and water.',
        'Pest and disease management': 'Monitor plants regularly for signs of pests and diseases and take appropriate measures such as using organic pesticides or practicing crop rotation to prevent infestations.',
        'Support': 'Consider providing support for the developing fruit by using trellises or slings to prevent them from touching the ground and reduce the risk of rot.',
        'Harvesting':'Watermelons are ready for harvest when the tendrils near the stem turn brown, and the underside of the fruit turns creamy yellow. Harvest by cutting the stem with a sharp knife, leaving a few inches attached to the fruit.'
        
    }
    
}

# %%
{
    'Duration':'',
    'Environment':{
        'Rainfall':'',
        'Temperatue':'',
        'Humidity':'',
    },
    'Soil':{
        'Nitrogen':'',
        'Phoshorous':'',
        'Potassiun':'',
        'ph':'',
    },
    'Cultivate':{
        
    }
    
}
